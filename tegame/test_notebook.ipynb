# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tegame import tegame
from tegame import is_empty_lists, is_list_of
from contextlib import redirect_stdout

# %%
mygame = tegame(verbose=True)

redirect_stdout(mygame.run_game,"output.txt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 mygame = tegame(verbose=True)
# ----> 3 redirect_stdout(mygame.run_game,"output.txt")
#
# TypeError: _RedirectStream.__init__() takes 2 positional arguments but 3 were given

# %%
hand=[40,41,50,51,70,1,2,3,20,30,31]
hand_ = deepcopy(hand)
hand_.sort()

pairs=[]
for i, card_i in enumerate(hand_):
    combo = []
    combo.append(i)
    old = card_i
    if card_i in pairs: continue
    for j, card_j in enumerate(hand_):
        if card_j - old == 10:
            combo.append(j)
            old = card_j
    if is_empty_lists(pairs):
        if (len(combo) > 1) : pairs.append(combo)
    else:
        if (len(combo) > 1) and not is_list_of(pairs,combo) : pairs.append(combo)
pairs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 hand=[40,41,50,51,70,1,2,3,20,30,31]
# ----> 2 hand_ = deepcopy(hand)
#       3 hand_.sort()
#       5 pairs=[]
#
# NameError: name 'deepcopy' is not defined

# %%
def redirect_to_file(func, filename: str):
    with open(filename, 'w') as f:
        with contextlib.redirect_stdout(f):
            func()

# Usage
#redirect_to_file(my_function, "output.txt")
