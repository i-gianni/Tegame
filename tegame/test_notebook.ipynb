# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tegame import tegame

# %%
mygame = tegame(verbose=True)

# %%
mygame.restart()
mygame.print_stat()
mygame.verbose=False
mygame.run_game()
# Out:
# Current deck is
#  37  58  87  17  15  70  50  80  59  82  94  26  24  40  73  56  51  55   6  78   2  34  30  61  27
#  90  36  60  62  38  53  92  16  88  86  95  49  83  22  81   8  74  44  84  21  77  79  67  98  48
#  97  14  76  46  33  99   4  71  12   7  31  65  89  42  68  39  25  11  20  10  29   9  35  96  69
#  63  85  57  43  23  52  47  45  19
#
# Current piles are
# 0:   1
# 1:   1
# 2: 100
# 3: 100
#
# Current player hands are
# Player 0: 28  91  75  93   5  13  64
# Player 1: 66   3  18  72  41  32  54
#
# ...
# New turn for player 0
# ...
#
# Mandatory move #0
#
# DECISION:
# Player 0 places card: 5 on pile 1
#
# Mandatory move #1
#
# DECISION:
# Player 0 places card: 93 on pile 2
#
# One more move?
#
# DECISION:
# Player 0 places card: 91 on pile 2
#
# One more move?
#
# No other meaningfull moves, turn is ending
# #played cards: 3
#
# Current piles are
# 0:   1
# 1:   1   5
# 2: 100  93  91
# 3: 100
#
# ...
# New turn for player 1
# ...
#
# Mandatory move #0
#
# DECISION:
# ...
