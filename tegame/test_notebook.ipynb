# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tegame

# %%
tegame.new_game()

# %%
tegame.run_game()
# Out:
# player  0  , hand:  [28, 25, 39, 50, 69, 78, 57]
#
# Printing Piles
#   1
#   1
# 100
# 100
#
#
# Interaction
# Card  98  playable on pile  2 with delta  2
#
# Card placed:  78 on pile  3
#
# Interaction
# Card  88  playable on pile  3 with delta  -10
#
# Card placed:  69 on pile  3
# n. played cards:  2
#
# player  1  , hand:  [84, 88, 71, 9, 27, 98, 82]
#
# Printing Piles
#   1
#   1
# 100
# 100  78  69
#
#
# Interaction
# Card  58  playable on pile  3 with delta  11
#
# Card placed:  98 on pile  2
#
# Interaction
# Card  58  playable on pile  3 with delta  11
#
# Card placed:  9 on pile  0
# n. played cards:  2
#
# player  0  , hand:  [28, 25, 39, 50, 57, 58, 48]
#
# Printing Piles
#   1   9
#   1
# 100  98
# 100  78  69
#
#
# Interaction
# Card  88  playable on pile  2 with delta  10
#
# Card placed:  58 on pile  3
#
# Interaction
# Card  88  playable on pile  2 with delta  10
#
# Card placed:  57 on pile  3
# n. played cards:  2
#
# ...
