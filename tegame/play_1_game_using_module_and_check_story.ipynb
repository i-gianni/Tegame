# %%
from tegame import *
import pickle
# %load_ext autoreload
# %autoreload 2

# %%
tegame_obj = Tegame(
    players=2,
    verb_lvl=2,
    thresh_secondchoice=4,
    thresh_nonmandatory=2)

tegame_obj.restart()

# ,
#     thresh_secondchoice=5,
#     thresh_nonmandatory=10)

with open("../ML_pytorch/Tegame/tegame/game_state.pkl", "rb") as f:
    state = pickle.load(f)

tegame_obj.set_state(state)

# %%
tegame_obj.run_game();
# Out:
# ###################
#  STARTING NEW GAME
# ###################
#
# ...
# New turn for player 0
# ...
#
# Current players hands are
# Player 0:  3  17  22  30  32  42  59
# Player 1: 12  24  45  56  63  67  69
#
# DECISION:
# Player 0 places card: 3 on pile 1
#
# DECISION:
# Player 0 places card: 17 on pile 0
#
# DECISION:
# Player 0 places card: 42 on pile 0
#
# DECISION:
# Player 0 places card: 32 on pile 0
#
# DECISION:
# Player 0 places card: 22 on pile 0
#
# Current piles are
# 0:   1  17  42  32  22
# 1:   1   3
# 2: 100
# 3: 100
#
# ...
# New turn for player 1
# ...
#
# Current players hands are
# Player 0: 30  59  39  84  31  25  74
# Player 1: 12  24  45  56  63  67  69
#
# DECISION:
# Player 1 places card: 12 on pile 0
#
# DECISION:
# Player 1 places card: 24 on pile 0
#
# Current piles are
# 0:   1  17  42  32  22  12  24
# 1:   1   3
# 2: 100
# 3: 100
#
# ...
# New turn for player 0
# ...
#
# Current players hands are
# Player 0: 25  30  31  39  59  74  84
# Player 1: 45  56  63  67  69  41  34
#
# ...
