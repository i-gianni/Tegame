# %%
from tegame import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tegame_obj = Tegame(verb_lvl=2)
tegame_obj.restart()
tegame_obj.run_game();
# Out:
# ###################
#  STARTING NEW GAME
# ###################
#
# ...
# New turn for player 0
# ...
#
# Current players hands are
# Player 0:  9  28  40  43  70  92  97
# Player 1: 13  19  26  37  54  59  61
#
# DECISION:
# Player 0 places card: 97 on pile 2
#
# DECISION:
# Player 0 places card: 92 on pile 2
#
# Current piles are
# 0:   1
# 1:   1
# 2: 100  97  92
# 3: 100
#
# ...
# New turn for player 1
# ...
#
# Current players hands are
# Player 0:  9  28  40  43  70  34  65
# Player 1: 13  19  26  37  54  59  61
#
# DECISION:
# Player 1 places card: 13 on pile 1
#
# DECISION:
# Player 1 places card: 19 on pile 1
#
# Current piles are
# 0:   1
# 1:   1  13  19
# 2: 100  97  92
# 3: 100
#
# ...
# New turn for player 0
# ...
#
# Current players hands are
# Player 0:  9  28  34  40  43  65  70
# Player 1: 26  37  54  59  61  10  73
#
# DECISION:
# Player 0 places card: 9 on pile 1
#
# DECISION:
# Player 0 places card: 70 on pile 2
#
# Current piles are
# 0:   1
# 1:   1  13  19   9
# 2: 100  97  92  70
# 3: 100
#
# ...
